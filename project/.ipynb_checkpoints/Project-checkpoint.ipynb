# %%
import csv
f = open("motor_vehicles.csv","rb")
reader = csv.reader(f)
country=[]
carnum=[]
x=0
for row in reader:
    
    if x != 0:
        
        
        a=row[1].split()
        c=row[52].split()
        d=map(float,c)
        
        
    
        if (x>=52):
            country.append(a[0])
            carnum.append(d[0])
    x+=1
print country
print carnum

from pylab import *
bar(country,carnum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-4d7f19f023f6> in <module>()
#      24
#      25 from pylab import *
# ---> 26 bar(country,carnum)
#      27
#      28
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in bar(left, height, width, bottom, hold, **kwargs)
#    2087         ax.hold(hold)
#    2088     try:
# -> 2089         ret = ax.bar(left, height, width, bottom, **kwargs)
#    2090         draw_if_interactive()
#    2091     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    4782             r.get_path()._interpolation_steps = 100
#    4783             #print r.get_label(), label, 'label' in kwargs
# -> 4784             self.add_patch(r)
#    4785             patches.append(r)
#    4786
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in add_patch(self, p)
#    1487         if p.get_clip_path() is None:
#    1488             p.set_clip_path(self.patch)
# -> 1489         self._update_patch_limits(p)
#    1490         self.patches.append(p)
#    1491         p._remove_method = lambda h: self.patches.remove(h)
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in _update_patch_limits(self, patch)
#    1505         vertices = patch.get_path().vertices
#    1506         if vertices.size > 0:
# -> 1507             xys = patch.get_patch_transform().transform(vertices)
#    1508             if patch.get_data_transform() != self.transData:
#    1509                 transform = (patch.get_data_transform() +
#
# /usr/lib/pymodules/python2.7/matplotlib/patches.pyc in get_patch_transform(self)
#     545
#     546     def get_patch_transform(self):
# --> 547         self._update_patch_transform()
#     548         return self._rect_transform
#     549
#
# /usr/lib/pymodules/python2.7/matplotlib/patches.pyc in _update_patch_transform(self)
#     541         width = self.convert_xunits(self._width)
#     542         height = self.convert_yunits(self._height)
# --> 543         bbox = transforms.Bbox.from_bounds(x, y, width, height)
#     544         self._rect_transform = transforms.BboxTransformTo(bbox)
#     545
#
# /usr/lib/pymodules/python2.7/matplotlib/transforms.pyc in from_bounds(x0, y0, width, height)
#     743         *width* and *height* may be negative.
#     744         """
# --> 745         return Bbox.from_extents(x0, y0, x0 + width, y0 + height)
#     746
#     747     @staticmethod
#
# TypeError: cannot concatenate 'str' and 'float' objects
# ['LMC', 'LMY', 'LTU', 'LUX', 'LVA', 'MAC', 'MDA', 'MDV', 'MEX', 'MLT', 'MUS', 'MYS', 'NAC', 'NLD', 'NOC', 'NOR', 'NZL', 'OEC', 'OED', 'PAN', 'PER', 'PHL', 'POL', 'PRI', 'ROU', 'RUS', 'SAS', 'SGP', 'SRB', 'SUR', 'SVK', 'SVN', 'SWE', 'TUN', 'TUR', 'UKR', 'UMC', 'URY', 'USA']
# [26.5820314777107, 55.0244665436244, 555.0, 739.0, 459.0, 161.0, 146.0, 24.0, 276.380381960645, 679.276383168944, 166.0, 350.0, 782.684938386972, 523.326849065778, 285.124590394969, 578.0, 718.0, 627.08712756366, 563.125136279828, 126.171936750883, 68.0, 29.3519455345178, 508.0, 596.0, 230.0, 271.0, 17.3962306822512, 147.85648408052, 255.869493225963, 280.551814368723, 348.0, 566.0, 519.0, 118.377474239156, 142.0, 167.0, 89.1600747852723, 200.0, 802.0]

# %%
from pylab import *


fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title('Number of Vehicles per 1000 people in each country')
ax.set_xlabel('country')
ax.set_ylabel('number of cars')
ax.bar(range (len(country)),carnum)
# Out:
# <Container object of 39 artists>

# %% [markdown]
# In the graph you can see the number of cars for every 1000 people in each country.Each number on the x axis represents a country but since we couldn't change the label to strings.
